# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/abhijit0323/EDA-assigment/main/adult.csv')

# %%
df.head()
# Out:
#    Age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country Income/year
# 0          2174             0              40   United-States       <=50K
# 1             0             0              13   United-States       <=50K
# 2             0             0              40   United-States       <=50K
# 3             0             0              40   United-States       <=50K
# 4             0             0              40            Cuba       <=50K

# %%
df.shape
# Out:
# (32561, 15)

# %%
dc=df.copy()

# %%
dc.shape
# Out:
# (32561, 15)

# %%
dc.head(3)
# Out:
#    Age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
#
#         marital-status          occupation    relationship    race    sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country Income/year
# 0          2174             0              40   United-States       <=50K
# 1             0             0              13   United-States       <=50K
# 2             0             0              40   United-States       <=50K

# %%
dc['Age'].unique()
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87], dtype=int64)

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  Income/year     32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
dc.isnull().sum()#no null values
# Out:
# Age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Income/year       0
# dtype: int64

# %%
df.head()
# Out:
#    Age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country Income/year
# 0          2174             0              40   United-States       <=50K
# 1             0             0              13   United-States       <=50K
# 2             0             0              40   United-States       <=50K
# 3             0             0              40   United-States       <=50K
# 4             0             0              40            Cuba       <=50K

# %%
def chk(data):
    for i in df['Age']:
        if type(i)=='int64':
            print('ok')
        else:
            print(i)

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  Income/year     32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
for i in dc.columns:
    num=[]
    obj=[]
    if dc[i].dtype=='int64':
        print(f'{i} is int64')
        num=num.append(dc[i])

    elif dc[i].dtype=='object':
        print(f'{i} is obj')
        obj=obj.append(i)
        
    else:
        print("why here")
# Out:
# Age is int64
# workclass is obj
# fnlwgt is int64
# education is obj
# education-num is int64
# marital-status is obj
# occupation is obj
# relationship is obj
# race is obj
# sex is obj
# capital-gain is int64
# capital-loss is int64
# hours-per-week is int64
# native-country is obj
# Income/year is obj

# %%
df.head(2)
# Out:
#    Age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         marital-status        occupation    relationship    race    sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country Income/year
# 0          2174             0              40   United-States       <=50K
# 1             0             0              13   United-States       <=50K

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  Income/year     32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
dc.columns
# Out:
# Index(['Age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Income/year'],
#       dtype='object')

# %%
dc.rename(
    columns={"fnlwgt": "final_weight", "education-num": "education_name", "marital-status": "marital_status","capital-gain": "capital_gain","capital-loss": "capital_loss","hours-per-week": "hours_per_eek","native-country": "native_country","Income/year":"Incomeperyear"},
    inplace=True,
)

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   final_weight    32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_name  32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_eek   32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  Incomeperyear   32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
dc[dc.Incomeperyear.str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [Age, workclass, final_weight, education, education_name, marital_status, occupation, relationship, race, sex, capital_gain, capital_loss, hours_per_eek, native_country, Incomeperyear]
# Index: []

# %%
dc.head()
# Out:
#    Age          workclass  final_weight   education  education_name  \
# 0   39          State-gov         77516   Bachelors              13
# 1   50   Self-emp-not-inc         83311   Bachelors              13
# 2   38            Private        215646     HS-grad               9
# 3   53            Private        234721        11th               7
# 4   28            Private        338409   Bachelors              13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_eek  native_country Incomeperyear
# 0          2174             0             40   United-States         <=50K
# 1             0             0             13   United-States         <=50K
# 2             0             0             40   United-States         <=50K
# 3             0             0             40   United-States         <=50K
# 4             0             0             40            Cuba         <=50K

# %%
dc.drop(dc.loc[dc['workclass']==' ?'].index, inplace=True)

# %%
dc.loc[dc['workclass']==' ?']
# Out:
# Empty DataFrame
# Columns: [Age, workclass, final_weight, education, education_name, marital_status, occupation, relationship, race, sex, capital_gain, capital_loss, hours_per_eek, native_country, Incomeperyear]
# Index: []

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30725 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             30725 non-null  int64
#  1   workclass       30725 non-null  object
#  2   final_weight    30725 non-null  int64
#  3   education       30725 non-null  object
#  4   education_name  30725 non-null  int64
#  5   marital_status  30725 non-null  object
#  6   occupation      30725 non-null  object
#  7   relationship    30725 non-null  object
#  8   race            30725 non-null  object
#  9   sex             30725 non-null  object
#  10  capital_gain    30725 non-null  int64
#  11  capital_loss    30725 non-null  int64
#  12  hours_per_eek   30725 non-null  int64
#  13  native_country  30725 non-null  object
#  14  Incomeperyear   30725 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.8+ MB

# %%
dc['Incomeperyear'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
dc.drop(dc.loc[dc['native_country']==' ?'].index, inplace=True)

# %%
dc.to_csv("census_cleaned_data.csv",index=False)

# %%
dc.tail()
# Out:
#        Age      workclass  final_weight    education  education_name  \
# 32556   27        Private        257302   Assoc-acdm              12
# 32557   40        Private        154374      HS-grad               9
# 32558   58        Private        151910      HS-grad               9
# 32559   22        Private        201490      HS-grad               9
# 32560   52   Self-emp-inc        287927      HS-grad               9
#
#             marital_status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital_gain  capital_loss  hours_per_eek  native_country Incomeperyear
# 32556             0             0             38   United-States         <=50K
# 32557             0             0             40   United-States          >50K
# 32558             0             0             40   United-States         <=50K
# 32559             0             0             20   United-States         <=50K
# 32560         15024             0             40   United-States          >50K

# %%
dc.head()
# Out:
#    Age          workclass  final_weight   education  education_name  \
# 0   39          State-gov         77516   Bachelors              13
# 1   50   Self-emp-not-inc         83311   Bachelors              13
# 2   38            Private        215646     HS-grad               9
# 3   53            Private        234721        11th               7
# 4   28            Private        338409   Bachelors              13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_eek  native_country Incomeperyear
# 0          2174             0             40   United-States         <=50K
# 1             0             0             13   United-States         <=50K
# 2             0             0             40   United-States         <=50K
# 3             0             0             40   United-States         <=50K
# 4             0             0             40            Cuba         <=50K

# %%
dc.sample(10)
# Out:
#        Age          workclass  final_weight      education  education_name  \
# 5361    18       Never-worked        206359           10th               6
# 16418   39            Private        230329      Bachelors              13
# 6327    24            Private        211527      Bachelors              13
# 19488   32            Private        328199      Assoc-voc              11
# 676     17            Private        102726           12th               8
# 10623   38          State-gov        267540   Some-college              10
# 20429   43   Self-emp-not-inc        316820   Some-college              10
# 1301    29            Private        419721        HS-grad               9
# 25247   23            Private         33423   Some-college              10
# 3676    44            Private        100584        HS-grad               9
#
#             marital_status          occupation    relationship  \
# 5361         Never-married                   ?       Own-child
# 16418   Married-civ-spouse               Sales         Husband
# 6327         Never-married        Adm-clerical   Not-in-family
# 19488             Divorced     Exec-managerial       Unmarried
# 676          Never-married       Other-service       Own-child
# 10623            Separated        Adm-clerical       Unmarried
# 20429   Married-civ-spouse     Farming-fishing         Husband
# 1301         Never-married       Other-service       Unmarried
# 25247        Never-married               Sales   Not-in-family
# 3676    Married-civ-spouse   Machine-op-inspct         Husband
#
#                       race      sex  capital_gain  capital_loss  \
# 5361                 White     Male             0             0
# 16418                White     Male             0             0
# 6327                 White     Male             0             0
# 19488                White   Female             0             0
# 676                  White     Male             0             0
# 10623                Black   Female             0             0
# 20429                White     Male             0             0
# 1301                 Black   Female             0             0
# 25247                White   Female             0             0
# 3676    Amer-Indian-Eskimo     Male             0             0
#
#        hours_per_eek  native_country Incomeperyear
# 5361              40   United-States         <=50K
# 16418             40          Canada          >50K
# 6327              30   United-States         <=50K
# 19488             40   United-States         <=50K
# 676               16   United-States         <=50K
# 10623             38   United-States         <=50K
# 20429             84   United-States         <=50K
# 1301              40           Japan         <=50K
# 25247             30   United-States         <=50K
# 3676              40   United-States         <=50K

# %%
dc.describe(include='all').T
# Out:
#                   count unique                  top   freq           mean  \
# Age             30169.0    NaN                  NaN    NaN      38.433757
# workclass         30169      8              Private  22286            NaN
# final_weight    30169.0    NaN                  NaN    NaN  189802.232291
# education         30169     16              HS-grad   9841            NaN
# education_name  30169.0    NaN                  NaN    NaN      10.120687
# marital_status    30169      7   Married-civ-spouse  14066            NaN
# occupation        30169     15       Prof-specialty   4038            NaN
# relationship      30169      6              Husband  12463            NaN
# race              30169      5                White  25938            NaN
# sex               30169      2                 Male  20385            NaN
# capital_gain    30169.0    NaN                  NaN    NaN    1091.754483
# capital_loss    30169.0    NaN                  NaN    NaN      88.351984
# hours_per_eek   30169.0    NaN                  NaN    NaN      40.928337
# native_country    30169     41        United-States  27511            NaN
# Incomeperyear     30169      2                <=50K  22661            NaN
#
#                           std      min       25%       50%       75%  \
# Age                 13.136121     17.0      28.0      37.0      47.0
# workclass                 NaN      NaN       NaN       NaN       NaN
# final_weight    105653.158358  13769.0  117634.0  178429.0  237624.0
# education                 NaN      NaN       NaN       NaN       NaN
# education_name       2.550235      1.0       9.0      10.0      13.0
# marital_status            NaN      NaN       NaN       NaN       NaN
# occupation                NaN      NaN       NaN       NaN       NaN
# relationship              NaN      NaN       NaN       NaN       NaN
# race                      NaN      NaN       NaN       NaN       NaN
# sex                       NaN      NaN       NaN       NaN       NaN
# capital_gain      7405.505862      0.0       0.0       0.0       0.0
# capital_loss       404.253703      0.0       0.0       0.0       0.0
# hours_per_eek       11.982022      1.0      40.0      40.0      45.0
# native_country            NaN      NaN       NaN       NaN       NaN
# Incomeperyear             NaN      NaN       NaN       NaN       NaN
#
#                       max
# Age                  90.0
# workclass             NaN
# final_weight    1484705.0
# education             NaN
# education_name       16.0
# marital_status        NaN
# occupation            NaN
# relationship          NaN
# race                  NaN
# sex                   NaN
# capital_gain      99999.0
# capital_loss       4356.0
# hours_per_eek        99.0
# native_country        NaN
# Incomeperyear         NaN

# %%
dc.head()
# Out:
#    Age          workclass  final_weight   education  education_name  \
# 0   39          State-gov         77516   Bachelors              13
# 1   50   Self-emp-not-inc         83311   Bachelors              13
# 2   38            Private        215646     HS-grad               9
# 3   53            Private        234721        11th               7
# 4   28            Private        338409   Bachelors              13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_eek  native_country Incomeperyear
# 0          2174             0             40   United-States         <=50K
# 1             0             0             13   United-States         <=50K
# 2             0             0             40   United-States         <=50K
# 3             0             0             40   United-States         <=50K
# 4             0             0             40            Cuba         <=50K

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30169 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             30169 non-null  int64
#  1   workclass       30169 non-null  object
#  2   final_weight    30169 non-null  int64
#  3   education       30169 non-null  object
#  4   education_name  30169 non-null  int64
#  5   marital_status  30169 non-null  object
#  6   occupation      30169 non-null  object
#  7   relationship    30169 non-null  object
#  8   race            30169 non-null  object
#  9   sex             30169 non-null  object
#  10  capital_gain    30169 non-null  int64
#  11  capital_loss    30169 non-null  int64
#  12  hours_per_eek   30169 non-null  int64
#  13  native_country  30169 non-null  object
#  14  Incomeperyear   30169 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
dc['native_country'].value_counts(normalize=True)
# Out:
#  United-States                 0.911896
#  Mexico                        0.020219
#  Philippines                   0.006232
#  Germany                       0.004243
#  Puerto-Rico                   0.003613
#  Canada                        0.003547
#  India                         0.003315
#  El-Salvador                   0.003315
#  Cuba                          0.003049
#  England                       0.002851
#  Jamaica                       0.002652
#  South                         0.002353
#  China                         0.002254
#  Italy                         0.002254
#  Dominican-Republic            0.002221
#  Vietnam                       0.002121
#  Guatemala                     0.002088
#  Japan                         0.001956
#  Poland                        0.001856
#  Columbia                      0.001856
#  Iran                          0.001392
#  Taiwan                        0.001392
#  Haiti                         0.001392
#  Portugal                      0.001127
#  Nicaragua                     0.001094
#  Peru                          0.000994
#  Greece                        0.000961
#  France                        0.000895
#  Ecuador                       0.000895
#  Ireland                       0.000796
#  Hong                          0.000630
#  Cambodia                      0.000597
#  Trinadad&Tobago               0.000597
#  Thailand                      0.000563
#  Laos                          0.000563
#  Yugoslavia                    0.000530
#  Outlying-US(Guam-USVI-etc)    0.000464
#  Hungary                       0.000431
#  Honduras                      0.000398
#  Scotland                      0.000365
#  Holand-Netherlands            0.000033
# Name: native_country, dtype: float64

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30169 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             30169 non-null  int64
#  1   workclass       30169 non-null  object
#  2   final_weight    30169 non-null  int64
#  3   education       30169 non-null  object
#  4   education_name  30169 non-null  int64
#  5   marital_status  30169 non-null  object
#  6   occupation      30169 non-null  object
#  7   relationship    30169 non-null  object
#  8   race            30169 non-null  object
#  9   sex             30169 non-null  object
#  10  capital_gain    30169 non-null  int64
#  11  capital_loss    30169 non-null  int64
#  12  hours_per_eek   30169 non-null  int64
#  13  native_country  30169 non-null  object
#  14  Incomeperyear   30169 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
plt.figure(figsize=(15,15))
sns.countplot(x=dc['native_country'])
# Out:
# <AxesSubplot: xlabel='native_country', ylabel='count'>

# %%
dc["native_country"].value_counts().plot.pie(y=dc["native_country"],figsize=(10,10),autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='native_country'>

# %%
sns.kdeplot(dc['Age'])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %%
sns.countplot(x=df["sex"])
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(15,15))
sns.countplot(x=df["race"])
# Out:
# <AxesSubplot: xlabel='race', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  Income/year     32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
plt.figure(figsize=(15,15))
sns.countplot(x=df["education"])
# Out:
# <AxesSubplot: xlabel='education', ylabel='count'>

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'workclass', 'education']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=dc[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
df.head()
# Out:
#    Age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country Income/year
# 0          2174             0              40   United-States       <=50K
# 1             0             0              13   United-States       <=50K
# 2             0             0              40   United-States       <=50K
# 3             0             0              40   United-States       <=50K
# 4             0             0              40            Cuba       <=50K

# %%
numeric_features = [feature for feature in dc.columns if dc[feature].dtype != 'O']

# %%
categorical_features = [feature for feature in dc.columns if dc[feature].dtype == 'O']

# %%
numeric_features
# Out:
# ['Age',
#  'final_weight',
#  'education_name',
#  'capital_gain',
#  'capital_loss',
#  'hours_per_eek']

# %%
categorical_features
# Out:
# ['workclass',
#  'education',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native_country',
#  'Incomeperyear']

# %%
sns.kdeplot(df['Age'])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=dc[numeric_features[i]],shade=True, color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
dc["race"].value_counts().plot.pie(y=dc["race"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='race'>

# %%
dc_cat=dc["native_country"].value_counts()[:10]
category = pd.DataFrame(dc['native_country'].value_counts()) 
plt.figure(figsize=(15,6))
sns.barplot(x=dc_cat, y ='native_country',data = category[:10],palette='hls')
plt.title('Top 10 App Countrywise Workforce')
plt.xticks(rotation=90)
plt.show()

# %%
categorical_features
# Out:
# ['workclass',
#  'education',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native_country',
#  'Incomeperyear']

# %%
numeric_features
# Out:
# ['Age',
#  'final_weight',
#  'education_name',
#  'capital_gain',
#  'capital_loss',
#  'hours_per_eek']

# %%
dc.head(1)
# Out:
#    Age   workclass  final_weight   education  education_name  marital_status  \
# 0   39   State-gov         77516   Bachelors              13   Never-married
#
#       occupation    relationship    race    sex  capital_gain  capital_loss  \
# 0   Adm-clerical   Not-in-family   White   Male          2174             0
#
#    hours_per_eek  native_country Incomeperyear
# 0             40   United-States         <=50K

# %%
dc_age_capital=dc.groupby(['Age'])['capital_gain'].sum().sort_values(ascending=False).reset_index()

# %%
dc['Age'].unique()
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 34, 25, 43, 40,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 47, 46,
#        36, 79, 27, 18, 33, 76, 55, 61, 70, 64, 71, 66, 51, 58, 26, 17, 60,
#        90, 75, 65, 77, 62, 63, 67, 74, 72, 69, 68, 73, 81, 78, 88, 80, 84,
#        83, 85, 82, 86], dtype=int64)

# %%
plt.figure(figsize=(18,18))
sns.barplot(x="Age",y="capital_gain",data=dc_age_capital)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='capital_gain'>

# %%
plt.figure(figsize = (30,30))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Age' , y = 'capital_gain' , data = dc_age_capital )
ax.set_xlabel('Age')
ax.set_ylabel('')
ax.set_title("Max capital gain", size = 20)
# Out:
# Text(0.5, 1.0, 'Max capital gain')

# %%
dc_education_capital=dc.groupby(['education'])['capital_gain'].sum().sort_values(ascending=False).reset_index()

# %%
dc_education_capital
# Out:
#         education  capital_gain
# 0       Bachelors       8751485
# 1     Prof-school       5816544
# 2         HS-grad       5799557
# 3         Masters       4155939
# 4    Some-college       3941922
# 5       Doctorate       1886764
# 6       Assoc-voc        963709
# 7      Assoc-acdm        559361
# 8            10th        324650
# 9            11th        227616
# 10            9th        161206
# 11        7th-8th        136300
# 12           12th        100094
# 13        5th-6th         48971
# 14      Preschool         45818
# 15        1st-4th         17205

# %%
dfa=dc.groupby(['education','native_country'])['capital_gain'].sum().reset_index()

# %%
dfa=dfa.sort_values('capital_gain',ascending=False)

# %%
dfa
# Out:
#          education               native_country  capital_gain
# 250      Bachelors                United-States       8395638
# 311        HS-grad                United-States       5397228
# 376    Prof-school                United-States       5200492
# 343        Masters                United-States       3936559
# 414   Some-college                United-States       3833106
# ..             ...                          ...           ...
# 149            9th                     Portugal             0
# 148            9th                       Poland             0
# 147            9th                  Philippines             0
# 146            9th   Outlying-US(Guam-USVI-etc)             0
# 416   Some-college                   Yugoslavia             0
#
# [417 rows x 3 columns]

# %%
dfa[dfa.education=='Bachelors'][:5]
# Out:
# Empty DataFrame
# Columns: [education, native_country, capital_gain]
# Index: []

# %%
dc.head(2)
# Out:
#    Age          workclass  final_weight   education  education_name  \
# 0   39          State-gov         77516   Bachelors              13
# 1   50   Self-emp-not-inc         83311   Bachelors              13
#
#         marital_status        occupation    relationship    race    sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    capital_gain  capital_loss  hours_per_eek  native_country Incomeperyear
# 0          2174             0             40   United-States         <=50K
# 1             0             0             13   United-States         <=50K

# %%
pip install jupyterthemes
# Out:
# Requirement already satisfied: jupyterthemes in c:\users\abhijit singh\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: lesscpy>=0.11.2 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyterthemes) (0.15.1)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyterthemes) (3.6.0)
# Requirement already satisfied: ipython>=5.4.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyterthemes) (7.31.1)
# Requirement already satisfied: notebook>=5.6.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyterthemes) (6.4.12)
# Requirement already satisfied: jupyter-core in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyterthemes) (4.11.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (3.0.20)
# Requirement already satisfied: matplotlib-inline in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.6)
# Requirement already satisfied: setuptools>=18.5 in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (63.4.1)
# Requirement already satisfied: backcall in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: decorator in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: traitlets>=4.2 in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.18.1)
# Requirement already satisfied: colorama in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.4.5)
# Requirement already satisfied: pygments in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (2.11.2)
# Requirement already satisfied: ply in c:\users\abhijit singh\anaconda3\lib\site-packages (from lesscpy>=0.11.2->jupyterthemes) (3.11)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.9)
# Requirement already satisfied: numpy>=1.19 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (21.3)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (7.3.4)
# Requirement already satisfied: jinja2 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (3.0.3)
# Requirement already satisfied: nbformat in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (5.5.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.5.5)
# Requirement already satisfied: tornado>=6.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.1)
# Requirement already satisfied: argon2-cffi in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.13.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (23.2.0)
# Requirement already satisfied: prometheus-client in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.14.1)
# Requirement already satisfied: ipython-genutils in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: ipykernel in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.15.2)
# Requirement already satisfied: nbconvert>=5 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.4.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyter-core->jupyterthemes) (302)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=5.6.0->jupyterthemes) (0.4)
# Requirement already satisfied: testpath in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.11.1)
# Requirement already satisfied: bleach in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jinja2->notebook>=5.6.0->jupyterthemes) (2.1.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.16.0)
# Requirement already satisfied: fastjsonschema in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\abhijit singh\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\abhijit singh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->jupyterthemes) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=5.6.0->jupyterthemes) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\abhijit singh\anaconda3\lib\site-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: psutil in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (1.5.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (21.4.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\abhijit singh\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\abhijit singh\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\abhijit singh\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t monokai

# %%
pip install --upgrade jupyterthemes
# Out:
# Requirement already satisfied: jupyterthemes in c:\users\abhijit singh\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: lesscpy>=0.11.2 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyterthemes) (0.15.1)
# Requirement already satisfied: jupyter-core in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyterthemes) (4.11.1)
# Requirement already satisfied: ipython>=5.4.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyterthemes) (7.31.1)
# Requirement already satisfied: notebook>=5.6.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyterthemes) (6.4.12)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyterthemes) (3.6.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.18.1)
# Requirement already satisfied: colorama in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.4.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (63.4.1)
# Requirement already satisfied: pickleshare in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: decorator in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (3.0.20)
# Requirement already satisfied: backcall in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: pygments in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (2.11.2)
# Requirement already satisfied: matplotlib-inline in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.6)
# Requirement already satisfied: ply in c:\users\abhijit singh\anaconda3\lib\site-packages (from lesscpy>=0.11.2->jupyterthemes) (3.11)
# Requirement already satisfied: cycler>=0.10 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.4.2)
# Requirement already satisfied: numpy>=1.19 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.9)
# Requirement already satisfied: nbformat in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (5.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: ipykernel in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.15.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.13.1)
# Requirement already satisfied: jinja2 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (3.0.3)
# Requirement already satisfied: pyzmq>=17 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (23.2.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.4.4)
# Requirement already satisfied: prometheus-client in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.14.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (7.3.4)
# Requirement already satisfied: tornado>=6.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.1)
# Requirement already satisfied: ipython-genutils in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\abhijit singh\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.5.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyter-core->jupyterthemes) (302)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\abhijit singh\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=5.6.0->jupyterthemes) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: bleach in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.13)
# Requirement already satisfied: testpath in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.6.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.11.1)
# Requirement already satisfied: defusedxml in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jinja2->notebook>=5.6.0->jupyterthemes) (2.1.2)
# Requirement already satisfied: fastjsonschema in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\abhijit singh\anaconda3\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.16.0)
# Requirement already satisfied: wcwidth in c:\users\abhijit singh\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\abhijit singh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->jupyterthemes) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=5.6.0->jupyterthemes) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\abhijit singh\anaconda3\lib\site-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (1.5.1)
# Requirement already satisfied: psutil in c:\users\abhijit singh\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\abhijit singh\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.18.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\abhijit singh\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\abhijit singh\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\abhijit singh\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\abhijit singh\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
dc.head()
# Out:
#    Age          workclass  final_weight   education  education_name  \
# 0   39          State-gov         77516   Bachelors              13
# 1   50   Self-emp-not-inc         83311   Bachelors              13
# 2   38            Private        215646     HS-grad               9
# 3   53            Private        234721        11th               7
# 4   28            Private        338409   Bachelors              13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_eek  native_country Incomeperyear
# 0          2174             0             40   United-States         <=50K
# 1             0             0             13   United-States         <=50K
# 2             0             0             40   United-States         <=50K
# 3             0             0             40   United-States         <=50K
# 4             0             0             40            Cuba         <=50K

# %%
sns.countplot(dc['Incomeperyear'],palette='coolwarm',hue='sex',data=dc)
# Out:
# <AxesSubplot: xlabel='Incomeperyear', ylabel='count'>

# %%
dc["occupation"].value_counts().plot.pie(y=dc["occupation"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='occupation'>

# %%
dc["education"].value_counts().plot.pie(y=dc["education"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='education'>

# %%
plt.figure(figsize=(20,20))
sns.countplot(dc['marital_status'],palette='coolwarm',hue='sex',data=dc)
# Out:
# <AxesSubplot: xlabel='marital_status', ylabel='count'>

# %%
sns.countplot(dc['Incomeperyear'],palette='coolwarm',hue='race',data=dc)
# Out:
# <AxesSubplot: xlabel='Incomeperyear', ylabel='count'>
